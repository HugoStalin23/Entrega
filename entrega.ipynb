# %%
import pandas as pd

# %%
df = pd.read_json("https://proyectoird.000webhostapp.com/API_PROYECTO/Servdatos/mostrar_datos")

# %%
df
# Out:
#     id                fecha  temperatura  humedad  lluvia  luz  t_suelo
# 0    8  2020-12-02 03:15:42           28       78     179  239       18
# 1    9  2020-12-02 03:20:11           29       64     506   50       49
# 2   10  2020-12-02 03:29:08           30       62      50   50       49
# 3   11  2020-12-02 03:55:50           29       61      50   50       49
# 4   12  2020-12-02 03:56:21           29       60      50   50       49
# 5   13  2020-12-02 06:23:35           28       78     179  239       18
# 6   14  2020-12-02 06:24:58           28       78     179  239       18
# 7   15  2020-12-02 06:25:13           21       68     179  239       18
# 8   16  2020-12-02 06:25:29           21       70      78  239       18
# 9   17  2020-12-02 06:25:44           21       70      78   20       18
# 10  18  2020-12-02 06:26:51           28       78     179  239       18
# 11  19  2020-12-02 06:29:34           28       78     179  239       18
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 47 entries, 0 to 46
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           47 non-null     int64
#  1   fecha        47 non-null     object
#  2   temperatura  47 non-null     int64
#  3   humedad      47 non-null     int64
#  4   lluvia       47 non-null     int64
#  5   luz          47 non-null     int64
#  6   t_suelo      47 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 2.7+ KB

# %%
df.describe()
# Out:
#               id  temperatura    humedad      lluvia         luz    t_suelo
# count  47.000000    47.000000  47.000000   47.000000   47.000000  47.000000
# mean   31.000000    26.446809  68.638298   42.893617   55.297872  37.872340
# std    13.711309     3.160961   4.966958   91.162834   78.130024  30.492064
# min     8.000000    20.000000  60.000000    0.000000   19.000000   7.000000
# 25%    19.500000    24.000000  64.500000    2.500000   20.000000  10.000000
# 50%    31.000000    28.000000  69.000000    5.000000   20.000000  18.000000
# 75%    42.500000    29.000000  70.000000   33.500000   23.500000  76.000000
# max    54.000000    30.000000  78.000000  506.000000  239.000000  79.000000

# %%
relation = df[['temperatura', 'humedad', 'lluvia', 'luz', 't_suelo']]

# %%
relation.head()
# Out:
#    temperatura  humedad  lluvia  luz  t_suelo
# 0           28       78     179  239       18
# 1           29       64     506   50       49
# 2           30       62      50   50       49
# 3           29       61      50   50       49
# 4           29       60      50   50       49

# %%
import numpy as np

# %%
import seaborn as sns

# %%
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
sns.pairplot(relation, kind='reg')

# %%
sns.distplot(df.temperatura)
# Out:
# /home/hugostalin/my_project_dir/my_project_env/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='temperatura', ylabel='Density'>

# %%
sns.distplot(df.humedad)
# Out:
# /home/hugostalin/my_project_dir/my_project_env/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='humedad', ylabel='Density'>

# %%
sns.distplot(df.lluvia)
# Out:
# /home/hugostalin/my_project_dir/my_project_env/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='lluvia', ylabel='Density'>

# %%
sns.distplot(df.luz)
# Out:
# /home/hugostalin/my_project_dir/my_project_env/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='luz', ylabel='Density'>

# %%
sns.distplot(df.t_suelo)
# Out:
# /home/hugostalin/my_project_dir/my_project_env/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='t_suelo', ylabel='Density'>

# %%
sns.lmplot(x='temperatura', y='humedad', data=df)

# %%
df = df.astype({"temperatura":'float',
                "humedad":'float',
                "lluvia":'float',
                "luz":'float',
                "t_suelo":'float',
                })

# %%
df
# Out:
#     id                fecha  temperatura  humedad  lluvia    luz  t_suelo
# 0    8  2020-12-02 03:15:42         28.0     78.0   179.0  239.0     18.0
# 1    9  2020-12-02 03:20:11         29.0     64.0   506.0   50.0     49.0
# 2   10  2020-12-02 03:29:08         30.0     62.0    50.0   50.0     49.0
# 3   11  2020-12-02 03:55:50         29.0     61.0    50.0   50.0     49.0
# 4   12  2020-12-02 03:56:21         29.0     60.0    50.0   50.0     49.0
# 5   13  2020-12-02 06:23:35         28.0     78.0   179.0  239.0     18.0
# 6   14  2020-12-02 06:24:58         28.0     78.0   179.0  239.0     18.0
# 7   15  2020-12-02 06:25:13         21.0     68.0   179.0  239.0     18.0
# 8   16  2020-12-02 06:25:29         21.0     70.0    78.0  239.0     18.0
# 9   17  2020-12-02 06:25:44         21.0     70.0    78.0   20.0     18.0
# 10  18  2020-12-02 06:26:51         28.0     78.0   179.0  239.0     18.0
# 11  19  2020-12-02 06:29:34         28.0     78.0   179.0  239.0     18.0
# ...
